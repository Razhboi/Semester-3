# %%
# !pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 39.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 22.4 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient, InsertOne

# Menggunakan string koneksi yang diberikan
client = MongoClient('mongodb+srv://noufalaji4:noufalaji4@cluster0.y6qah.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0')
db = client['university_db']
courses_collection = db['courses']

# Menyiapkan sekumpulan operasi untuk pendaftaran mahasiswa
operations = [
    InsertOne({'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics'}),
    InsertOne({'course': 'CS 102', 'enrollments': 25, 'department': 'Computer Science'}),
    InsertOne({'course': 'History 201', 'enrollments': 20, 'department': 'History'}),
    InsertOne({'course': 'Physics 202', 'enrollments': 15, 'department': 'Physics'})
]

# Melakukan operasi bulk write
courses_collection.bulk_write(operations)
print("Courses inserted successfully.")
# Out:
# Courses inserted successfully.

# %%
# Kueri untuk kursus dengan pendaftaran lebih dari 20
for course in courses_collection.find({'enrollments': {'$gt': 20}}):
    print(course)
# Out:
# {'_id': ObjectId('672ecabef0ce00b94632325e'), 'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics'}
# {'_id': ObjectId('672ecabef0ce00b94632325f'), 'course': 'CS 102', 'enrollments': 25, 'department': 'Computer Science'}

# %%
# Kueri untuk kursus di departemen Ilmu Komputer atau Matematika
for course in courses_collection.find({'department': {'$in': ['Computer Science', 'Mathematics']}}):
    print(course)
# Out:
# {'_id': ObjectId('672ecabef0ce00b94632325e'), 'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics'}
# {'_id': ObjectId('672ecabef0ce00b94632325f'), 'course': 'CS 102', 'enrollments': 25, 'department': 'Computer Science'}

# %%
# Rata-rata pendaftaran per departemen menggunakan agregasi
pipeline = [
    {'$group': {'_id': '$department', 'average_enrollment': {'$avg': '$enrollments'}}}
]
for result in courses_collection.aggregate(pipeline):
    print(result)
# Out:
# {'_id': 'History', 'average_enrollment': 20.0}
# {'_id': 'Computer Science', 'average_enrollment': 25.0}
# {'_id': 'Physics', 'average_enrollment': 15.0}
# {'_id': 'Mathematics', 'average_enrollment': 30.0}

# %%
# Pendaftaran maksimum per departemen
pipeline = [
    {'$group': {'_id': '$department', 'max_enrollment': {'$max': '$enrollments'}}}
]
for result in courses_collection.aggregate(pipeline):
    print(result)
# Out:
# {'_id': 'Physics', 'max_enrollment': 15}
# {'_id': 'History', 'max_enrollment': 20}
# {'_id': 'Mathematics', 'max_enrollment': 30}
# {'_id': 'Computer Science', 'max_enrollment': 25}

# %%
pipeline = [
    {'$project': {'course_name': '$course', 'department_name': '$department', 'enrollments': 1}}
]

for result in courses_collection.aggregate(pipeline):
    print(result)
# Out:
# {'_id': ObjectId('672ecabef0ce00b94632325e'), 'enrollments': 30, 'course_name': 'Math 101', 'department_name': 'Mathematics'}
# {'_id': ObjectId('672ecabef0ce00b94632325f'), 'enrollments': 25, 'course_name': 'CS 102', 'department_name': 'Computer Science'}
# {'_id': ObjectId('672ecabef0ce00b946323260'), 'enrollments': 20, 'course_name': 'History 201', 'department_name': 'History'}
# {'_id': ObjectId('672ecabef0ce00b946323261'), 'enrollments': 15, 'course_name': 'Physics 202', 'department_name': 'Physics'}

# %%
pipeline = [
    {'$addFields': {'enrollment_category': {'$cond': {'if': {'$gt': ['$enrollments', 20]}, 'then': 'high', 'else': 'low'}}}}
]

for result in courses_collection.aggregate(pipeline):
    print(result)
# Out:
# {'_id': ObjectId('672ecabef0ce00b94632325e'), 'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'enrollment_category': 'high'}
# {'_id': ObjectId('672ecabef0ce00b94632325f'), 'course': 'CS 102', 'enrollments': 25, 'department': 'Computer Science', 'enrollment_category': 'high'}
# {'_id': ObjectId('672ecabef0ce00b946323260'), 'course': 'History 201', 'enrollments': 20, 'department': 'History', 'enrollment_category': 'low'}
# {'_id': ObjectId('672ecabef0ce00b946323261'), 'course': 'Physics 202', 'enrollments': 15, 'department': 'Physics', 'enrollment_category': 'low'}
# {'_id': ObjectId('6731a87834c582c7beac9860'), 'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'enrollment_category': 'high'}
# {'_id': ObjectId('6731a87834c582c7beac9861'), 'course': 'CS 102', 'enrollments': 25, 'department': 'Computer Science', 'enrollment_category': 'high'}
# ...

# %%
pipeline = [
    {'$group': {'_id': '$department', 'course_count': {'$sum': 1}}}
]

for result in courses_collection.aggregate(pipeline):
    print(result) # Indented this line by 4 spaces
# Out:
# {'_id': 'Computer Science', 'course_count': 2}
# {'_id': 'Physics', 'course_count': 2}
# {'_id': 'History', 'course_count': 2}
# {'_id': 'Mathematics', 'course_count': 2}

# %%
courses = [
{'course': 'CS 103', 'enrollments': 30, 'department': 'Computer Science'},
{'course': 'CS 104', 'enrollments': 35, 'department': 'Computer Science'},
{'course': 'CS 105', 'enrollments': 40, 'department': 'Computer Science'}
]

result = courses_collection.insert_many(courses)
print('Courses inserted successfully')
# Out:
# Courses inserted successfully

# %%
client = MongoClient('mongodb+srv://noufalaji4:noufalaji4@cluster0.y6qah.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0')
db = client['university_db']
courses_collection = db['courses']

# Get the 'students' collection and assign it to students_collection
students_collection = db['students']  # This line is added

students_data = [
    {"name": "Noufal", "enrolled_courses": ["Math 103", "CS 205", "Physics 100"]},
    {"name": "Aji", "enrolled_courses": ["History 202", "Math 101", "CS 105"]},
    {"name": "Prasetyo", "enrolled_courses": ["Math 101", "CS 102"]},  # Tambahan
    {"name": "Wahyu", "enrolled_courses": ["History 201", "CS 104"]},   # Tambahan
    {"name": "David", "enrolled_courses": ["Physics 202", "CS 103"]},    # Tambahan
    {"name": "Raymond", "enrolled_courses": ["Math 201", "CS 205"]},     # Tambahan
    {"name": "Al", "enrolled_courses": ["Math 101", "CS 102", "CS 105"]},
    {"name": "Bob", "enrolled_courses": ["Physics 202", "Math 101", "CS 104"]},
    {"name": "Charl", "enrolled_courses": ["CS 102", "History 201", "CS 104"]},
    {"name": "Dani", "enrolled_courses": ["Math 101", "Physics 202", "CS 103"]},
    {"name": "Ella", "enrolled_courses": ["History 201", "CS 102", "CS 105"]},
    {"name": "Adam", "enrolled_courses": ["Physics 202", "CS 102"]},
    {"name": "Yuan", "enrolled_courses": ["History 201", "Math 101", "CS 103"]},
    {"name": "Luci", "enrolled_courses": ["CS 102", "Physics 202", "CS 105"]},
    {"name": "Saka", "enrolled_courses": ["Math 101", "History 201"]}
]

# Menyisipkan data siswa ke dalam koleksi
students_collection.insert_many(students_data)
print('Data siswa berhasil dimasukkan.')
# Out:
# Data siswa berhasil dimasukkan.

# %%
# Homework 3: Apply `$lookup` to join `courses` collection with `students` collection based on student enrollments.
# Apply $lookup to join courses collection with students collection based on student enrollments.

pipeline = [
    {'$lookup': {'from': 'students', 'localField': 'course', 'foreignField': 'enrolled_courses', 'as': 'enrolled_students'}},
    {'$project': {'course': 1, 'department': 1, 'enrollments': 1, 'enrolled_students': {'$map': {'input': '$enrolled_students', 'as': 'student', 'in': '$$student.name'}}}}
]

for result in courses_collection.aggregate(pipeline):
    print(result)
# Out:
# {'_id': ObjectId('672ecabef0ce00b94632325e'), 'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'enrolled_students': ['Aji', 'Prasetyo', 'Al', 'Bob', 'Dani', 'Yuan', 'Saka']}
# {'_id': ObjectId('672ecabef0ce00b94632325f'), 'course': 'CS 102', 'enrollments': 25, 'department': 'Computer Science', 'enrolled_students': ['Prasetyo', 'Al', 'Charl', 'Ella', 'Adam', 'Luci']}
# {'_id': ObjectId('672ecabef0ce00b946323260'), 'course': 'History 201', 'enrollments': 20, 'department': 'History', 'enrolled_students': ['Wahyu', 'Charl', 'Ella', 'Yuan', 'Saka']}
# {'_id': ObjectId('672ecabef0ce00b946323261'), 'course': 'Physics 202', 'enrollments': 15, 'department': 'Physics', 'enrolled_students': ['David', 'Bob', 'Dani', 'Adam', 'Luci']}
# {'_id': ObjectId('6731a87834c582c7beac9860'), 'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'enrolled_students': ['Aji', 'Prasetyo', 'Al', 'Bob', 'Dani', 'Yuan', 'Saka']}
# ...
